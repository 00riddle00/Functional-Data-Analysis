# %% [markdown]
# ## Set current dir to project root dir

# %%
path <- getwd()
markers <- c(".git", "Makefile", "renv.lock", ".Rprofile")
while (!any(file.exists(file.path(path, markers)))) {
  parent <- dirname(path)
  if (parent == path) stop("Could not find project root")
  path <- parent
}
setwd(path)
rm(path, parent, markers)

# %% [markdown]
# ## Activate project's local R env. using renv

# %%
if (file.exists("renv/activate.R")) {
  source("renv/activate.R")
} else {
  stop("Could not find renv/activate.R in project root")
}
# Out:
# - The project is out-of-sync -- use `renv::status()` for details.

# %% [markdown]
# ## Imports

# %%
library(readr)
library(dplyr)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %% [markdown]
# ## Read data

# %%
participants <- read_tsv("./ds006018/participants.tsv", show_col_types = FALSE)

# %%
current_data <- read_csv("./EDA/subject_metadata.csv", show_col_types = FALSE)
current_subset <- inner_join(participants, current_data,
                             by = c("participant_id" = "subject_id"))
current_subset
# Out:
#    participant_id Age_Grouped Gender Handedness
# 1  sub-001        18 to 22    female right
# 2  sub-002        23 to 26    male   right
# 3  sub-003        18 to 22    female right
# 4  sub-004        18 to 22    female right
# 5  sub-005        18 to 22    male   right
# 6  sub-006        18 to 22    female left
# 7  sub-007        18 to 22    female right
# 8  sub-008        18 to 22    male   right
# 9  sub-009        18 to 22    female right
# 10 sub-010        18 to 22    male   right
# 11 sub-011        18 to 22    male   right
# 12 sub-012        18 to 22    female right
# 13 sub-013        23 to 26    female right
# 14 sub-014        18 to 22    male   right
# 15 sub-016        18 to 22    male   right
# 16 sub-017        27 to 30    female right
# 17 sub-019        23 to 26    female right
# 18 sub-021        18 to 22    female right
# 19 sub-022        18 to 22    female right
# 20 sub-024        18 to 22    female right
# 21 sub-025        18 to 22    female right
# ...

# %% [markdown]
# ## Full data analysis

# %%
table(participants$ADHD_binary)
# Out:
#  0  1
# 75 33

# %%
table(participants$Gender)
# Out:
# cannot be disclosed              female                male
#                   1                  73                  53

# %%
sort(table(participants$Subjective_SES), decreasing = TRUE)
# Out:
#  4  6  5  3  7  2  1  8  9 10
# 27 22 20 17 15  8  6  6  2  2

# %% [markdown]
# ## Our subset analysis

# %%
table(current_subset$ADHD_binary)
# Out:
#  0  1
# 39 12

# %%
table(current_subset$Gender)
# Out:
# female   male
#     37     25

# %%
sort(table(current_subset$Subjective_SES), decreasing = TRUE)
# Out:
#  4  7  5  3  6  1  2  8  9
# 13 10  9  8  7  5  4  3  2
